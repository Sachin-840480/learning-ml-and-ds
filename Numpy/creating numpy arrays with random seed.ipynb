# %% [markdown]
# # Creating NumPy Arrays.

# %%
import numpy as np

# %%
sample_array = np.array([1, 2, 3])
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
ones = np.ones([2, 3])

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2, 3))

# %%
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0, 10, 2)

range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0 ,10, size=(3,5))

random_array
# Out:
# array([[7, 6, 2, 5, 4],
#        [1, 6, 6, 2, 6],
#        [6, 1, 5, 3, 9]], dtype=int32)

# %%
random_array.size
# Out:
# 15

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array2 = np.random.random((5, 3))

random_array2
# Out:
# array([[0.78535967, 0.35340661, 0.87271869],
#        [0.55734708, 0.83810922, 0.49227479],
#        [0.69739781, 0.37276596, 0.19838546],
#        [0.96735911, 0.26812601, 0.74081361],
#        [0.84017118, 0.16104442, 0.75123747]])

# %%
random_array2.shape
# Out:
# (5, 3)

# %%
random_array2.size
# Out:
# 15

# %%
random_array3 = np.random.rand(5, 3)

random_array3
# Out:
# array([[0.50997086, 0.69319203, 0.4157162 ],
#        [0.76283913, 0.70322984, 0.65758259],
#        [0.27733408, 0.27489301, 0.73793852],
#        [0.28049701, 0.1195384 , 0.14243473],
#        [0.05289979, 0.8401956 , 0.46391228]])

# %%
# Pseudo random Numbers.

#np.random.seed()

# %% [markdown]
# # NumPy Random Seed

# %%
# Pseudo random Numbers.

# np.random.seed()

# %%
np.random.seed(seed=0)
# np.random.seed(seed=999)
# np.random.seed(seed=445)
# np.random.seed(seed=145)

random_array4 = np.random.randint(10, size=(5, 3))

random_array4
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]], dtype=int32)

# %%
random_array4.shape
# Out:
# (5, 3)

# %%
np.random.seed(7)

random_array5 = np.random.random((5, 3))

random_array5
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %%
random_array5 = np.random.random((5, 3))

random_array5
# Out:
# array([[0.90959353, 0.21338535, 0.45212396],
#        [0.93120602, 0.02489923, 0.60054892],
#        [0.9501295 , 0.23030288, 0.54848992],
#        [0.90912837, 0.13316945, 0.52341258],
#        [0.75040986, 0.66901324, 0.46775286]])
