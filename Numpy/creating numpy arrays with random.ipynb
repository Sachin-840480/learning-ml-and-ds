# %% [markdown]
# # Creating NumPy Arrays.

# %%
import numpy as np

# %%
sample_array = np.array([1, 2, 3])
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
ones = np.ones([2, 3])

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2, 3))

# %%
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0, 10, 2)

range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0 ,10, size=(3,5))

random_array
# Out:
# array([[7, 4, 2, 5, 2],
#        [0, 6, 2, 7, 6],
#        [5, 7, 5, 0, 8]], dtype=int32)

# %%
random_array.size
# Out:
# 15

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array_2 = np.random.random((5, 3))

random_array_2
# Out:
# array([[0.45706937, 0.86312504, 0.44664788],
#        [0.73940546, 0.06898363, 0.13655291],
#        [0.36467804, 0.18695927, 0.56547078],
#        [0.63878154, 0.64127773, 0.74290444],
#        [0.33559901, 0.80708695, 0.80656875]])

# %%
random_array_2.shape
# Out:
# (5, 3)

# %%
random_array_2.size
# Out:
# 15

# %%
random_array_3 = np.random.rand(5, 3)

random_array_3
# Out:
# array([[0.31112181, 0.47366609, 0.19919764],
#        [0.28655636, 0.59873904, 0.75363333],
#        [0.53757717, 0.45554127, 0.48360345],
#        [0.85228248, 0.53121597, 0.30907114],
#        [0.11933411, 0.89114701, 0.71197371]])

# %%
# Pseudo random Numbers.

np.random.seed()

# %% [markdown]
# # NumPy Random Seed
