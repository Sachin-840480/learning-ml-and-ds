# %% [markdown]
# # Making figures with NumPy arrays

# %% [markdown]
# We want:
# * Line Plot.
# * Scatter Plot.
# * Bar Plot.
# * Horizotal Bar Plot.
# * Histogram.
# * Subplot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Line Plots

# %%
# Create some data.

x = np.linspace(0, 10, 100)

x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# Plot the data and create a line plot.

fig, ax = plt.subplots()
ax.plot(x, x**2);

# %% [markdown]
# ### Scatter Plot

# %%
# Use same data to make a scatter plot.

fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
# Another scatter plot.

fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %% [markdown]
# ### Bar Plots

# %%
# Make a plot from dictionary.
nut_butter_prices = {"Almond Butter" : 10,
                     "Peanut Butter" : 8,
                     "Cashew Butter" : 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())

# same thing but we can write it as 'height'backup.ipynb
# ax.bar(nut_butter_prices.keys(), height = nut_butter_prices.values())

ax.set(title="Satyam's Nut Butter Store",
       ylabel = "Price ($)")
plt.show()

# %%
# Horizontal bar Pot

fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram

# %%
# Making Some Data for histogram and plot it.

x = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  6.,  10.,  42., 116., 210., 234., 219., 115.,  39.,   9.]),
#  array([-3.59335101, -2.9351623 , -2.27697359, -1.61878489, -0.96059618,
#         -0.30240747,  0.35578124,  1.01396995,  1.67215866,  2.33034737,
#          2.98853608]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Subplots

# %% [markdown]
# #### Two options for subplots.

# %%
# Subplot option 1. (Recommended)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))

# Plot to each different axis.

ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([ 17.,  30.,  99., 172., 249., 223., 111.,  71.,  21.,   7.]),
#  array([-2.83467928, -2.23126158, -1.62784388, -1.02442618, -0.42100848,
#          0.18240922,  0.78582693,  1.38924463,  1.99266233,  2.59608003,
#          3.19949773]),
#  <BarContainer object of 10 artists>)

# %%
# Subplots Option 2.
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))

# Plot to each different axis (i.e index).
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([ 10.,  25.,  87., 166., 226., 223., 145.,  78.,  30.,  10.]),
#  array([-2.92889831, -2.34689498, -1.76489164, -1.1828883 , -0.60088496,
#         -0.01888162,  0.56312171,  1.14512505,  1.72712839,  2.30913173,
#          2.89113507]),
#  <BarContainer object of 10 artists>)

# %%
# Understanding the Axis of these Plots for both methods.

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

print(fig, (ax1, ax2), (ax3, ax4))

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

print(fig, ax)
# Out:
# Figure(1000x500) (<Axes: >, <Axes: >) (<Axes: >, <Axes: >)
# Figure(1000x500) [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]
